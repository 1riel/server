# %%
import os
if not hasattr(os, "_cwd"):
    os.chdir("../../")
    os._cwd = True

# %%
import os
import sys

sys.path.append(os.getcwd())


from pymongo import AsyncMongoClient

from Environment import *

client = AsyncMongoClient(
    MONGO_URL,
    connectTimeoutMS=5000,  # 5 second
    serverSelectionTimeoutMS=5000,  # 5 second
)

# %%
db = client["database"]
c_counter = db["c_counter"]
await c_counter.update_one({'_id':'init'}, {'$set': {'_id':'init'}}, upsert=True)
# Out:
# UpdateResult({'n': 1, 'nModified': 0, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
# counter = await db.c_counter.find_one_and_update(
#     {"_id": "c_template"},
#     {"$inc": {"seq": 1}},
#     upsert=True,
#     return_document=True,
# )
